# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid", font_scale=1.5)
# %matplotlib inline
import math
from sklearn.metrics import mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Studies/rohit/Ethereum 5 Year prices.csv', index_col='Date')

# %%
df.head()
# Out:
#              Price    Open    High     Low     Vol.
# Date
# 15/04/2018  533.90  502.52  534.18  502.52  988.29K
# 16/04/2018  511.82  533.89  537.32  498.87    1.03M
# 17/04/2018  503.19  511.75  520.86  501.73  826.71K
# 18/04/2018  525.66  503.24  526.41  502.02  759.15K
# 19/04/2018  567.49  525.74  570.15  522.15    1.04M

# %%
df = df["Price"].dropna()
df.size
# Out:
# 1827

# %%
plt.figure(figsize=(12,6))
plt.plot(df)

# %%
data = df.iloc[:]
hist = []
target = []
length = 90
for i in range(len(data)-length):
    x = data[i:i+length]
    y = data[i+length]
    hist.append(x)
    target.append(y)

# %%
print(hist[1][89])
print(data[90])
print(target[0])
# Out:
# 434.09
# 434.09
# 434.09

# %%
hist = np.array(hist)
target = np.array(target)
target = target.reshape(-1,1)

# %%
hist = np.array(hist)
target = np.array(target)
target = target.reshape(-1,1)

# %%
hist.shape
# Out:
# (1737, 90)

# %%
target.shape
# Out:
# (1737, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
hist_scaled = sc.fit_transform(hist)
target_scaled = sc.fit_transform(target)

# %%
hist_scaled = hist_scaled.reshape((len(hist_scaled), length, 1))
print(hist_scaled.shape)
# Out:
# (1737, 90, 1)

# %%
X_train = hist_scaled[:1637,:,:]
X_test = hist_scaled[1637:,:,:]
y_train = target_scaled[:1637,:]
y_test = target_scaled[1637:,:]

# %%
import tensorflow as tf
from tensorflow.keras import layers

# %%
model = tf.keras.Sequential()
model.add(layers.LSTM(units=32, return_sequences=True,
                  input_shape=(90,1), dropout=0.2))
model.add(layers.LSTM(units=32, return_sequences=True,
                  dropout=0.2))
model.add(layers.LSTM(units=32, dropout=0.2))
model.add(layers.Dense(units=1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 90, 32)            4352
#
#  lstm_1 (LSTM)               (None, 90, 32)            8320
#
#  lstm_2 (LSTM)               (None, 32)                8320
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 21,025
# Trainable params: 21,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
history = model.fit(X_train, y_train, epochs=30, batch_size=32)
# Out:
# Epoch 1/30
# 52/52 [==============================] - 10s 99ms/step - loss: 0.0176
# Epoch 2/30
# 52/52 [==============================] - 5s 92ms/step - loss: 0.0043
# Epoch 3/30
# 52/52 [==============================] - 4s 86ms/step - loss: 0.0042
# Epoch 4/30
# 52/52 [==============================] - 5s 101ms/step - loss: 0.0048
# Epoch 5/30
# 52/52 [==============================] - 5s 88ms/step - loss: 0.0048
# Epoch 6/30
# 52/52 [==============================] - 5s 88ms/step - loss: 0.0037
# Epoch 7/30
# 52/52 [==============================] - 5s 101ms/step - loss: 0.0037
# Epoch 8/30
# 52/52 [==============================] - 5s 87ms/step - loss: 0.0039
# Epoch 9/30
# 52/52 [==============================] - 5s 92ms/step - loss: 0.0039
# Epoch 10/30
# 52/52 [==============================] - 5s 95ms/step - loss: 0.0037
# Epoch 11/30
# 52/52 [==============================] - 4s 86ms/step - loss: 0.0047
# Epoch 12/30
# 52/52 [==============================] - 5s 100ms/step - loss: 0.0039
# Epoch 13/30
# 52/52 [==============================] - 5s 89ms/step - loss: 0.0033
# Epoch 14/30
# 52/52 [==============================] - 5s 87ms/step - loss: 0.0033
# Epoch 15/30
# 52/52 [==============================] - 5s 102ms/step - loss: 0.0039
# Epoch 16/30
# 52/52 [==============================] - 5s 87ms/step - loss: 0.0032
# Epoch 17/30
# 52/52 [==============================] - 5s 89ms/step - loss: 0.0037
# Epoch 18/30
# 52/52 [==============================] - 5s 100ms/step - loss: 0.0035
# Epoch 19/30
# 52/52 [==============================] - 5s 89ms/step - loss: 0.0036
# Epoch 20/30
# 52/52 [==============================] - 5s 95ms/step - loss: 0.0030
# Epoch 21/30
# 52/52 [==============================] - 5s 91ms/step - loss: 0.0033
# Epoch 22/30
# 52/52 [==============================] - 5s 89ms/step - loss: 0.0032
# Epoch 23/30
# 52/52 [==============================] - 5s 102ms/step - loss: 0.0032
# Epoch 24/30
# 52/52 [==============================] - 4s 85ms/step - loss: 0.0032
# Epoch 25/30
# 52/52 [==============================] - 4s 84ms/step - loss: 0.0028
# Epoch 26/30
# 52/52 [==============================] - 5s 102ms/step - loss: 0.0030
# Epoch 27/30
# 52/52 [==============================] - 5s 89ms/step - loss: 0.0031
# Epoch 28/30
# 52/52 [==============================] - 5s 90ms/step - loss: 0.0029
# Epoch 29/30
# 52/52 [==============================] - 5s 95ms/step - loss: 0.0027
# Epoch 30/30
# 52/52 [==============================] - 5s 87ms/step - loss: 0.0028

# %%
loss = history.history['loss']
epoch_count = range(1, len(loss) + 1)
plt.figure(figsize=(12,8))
plt.plot(epoch_count, loss, 'r--')
plt.legend(['Training Loss for Bitcoin'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();

# %%
pred = model.predict(X_test)
plt.figure(figsize=(12,8))
plt.plot(y_test, color='blue', label='Real')
plt.plot(pred, color='red', label='Prediction')
plt.title('Bitcoin Price Prediction')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 1s 19ms/step

# %%
pred_transformed = sc.inverse_transform(pred)
y_test_transformed = sc.inverse_transform(y_test)

pred = model.predict(X_test)
plt.figure(figsize=(12,8))
plt.plot(y_test_transformed, color='blue', label='Real')
plt.plot(pred_transformed, color='red', label='Prediction')
plt.title('Bitcoin Price Prediction')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 0s 22ms/step

# %%
math.sqrt(mean_squared_error(y_test_transformed, pred_transformed))
# Out:
# 112.9374106593641

# %%
from sklearn.metrics import mean_absolute_error as mae
error = mae(y_test_transformed, pred_transformed)
print("Mean absolute error : " + str(error))
# Out:
# Mean absolute error : 95.03512753906253

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

error2 = mean_absolute_percentage_error(y_test_transformed, pred_transformed)
print("MAPE: ", error2)
# Out:
# MAPE:  5.77516040972216
